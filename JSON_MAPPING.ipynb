# %%
import json
import os


path=r'C:\Users\Athira\OneDrive\Documents\Desktop\SIGN_LANGUAGE\sign_mp4'

d1={
'0':os.path.join(path, '0.mp4'),
'1':os.path.join(path, '1.mp4'),
'2':os.path.join(path, '2.mp4'),
'3':os.path.join(path, '3.mp4'),
'4':os.path.join(path, '4.mp4'),
'5':os.path.join(path, '5.mp4'),
'6':os.path.join(path, '6.mp4'),
'7':os.path.join(path, '7.mp4'),
'8':os.path.join(path, '8.mp4'),
'9':os.path.join(path, '9.mp4'),
'a':os.path.join(path, 'a.mp4'),
'b':os.path.join(path, 'b.mp4'),
'c':os.path.join(path, 'c.mp4'),
'd':os.path.join(path, 'd.mp4'),
'e':os.path.join(path, 'e.mp4'),
'f':os.path.join(path, 'f.mp4'),
'g':os.path.join(path, 'g.mp4'),
'h':os.path.join(path, 'h.mp4'),
'i':os.path.join(path, 'i.mp4'),
'j':os.path.join(path, 'j.mp4'),
'k':os.path.join(path, 'k.mp4'),
'l':os.path.join(path, 'l.mp4'),
'm':os.path.join(path, 'm.mp4'),
'n':os.path.join(path, 'n.mp4'),
'o':os.path.join(path, 'o.mp4'),
'p':os.path.join(path, 'p.mp4'),
'q':os.path.join(path, 'q.mp4'),
'r':os.path.join(path, 'r.mp4'),
's':os.path.join(path, 's.mp4'),
't':os.path.join(path, 't.mp4'),
'u':os.path.join(path, 'u.mp4'),
'v':os.path.join(path, 'v.mp4'),
'w':os.path.join(path, 'w.mp4'),
'x':os.path.join(path, 'x.mp4'),
'y':os.path.join(path, 'y.mp4'),
'z':os.path.join(path, 'z.mp4')
}
d2={
'nice':os.path.join(path, 'nice.mp4'),
'good':os.path.join(path, 'good.mp4'),
'morning':os.path.join(path, 'morning.mp4'),
'evening':os.path.join(path, 'evening.mp4'),
'night':os.path.join(path, 'night.mp4'),
'thankyou':os.path.join(path, 'thank_you.mp4'),
'welcome':os.path.join(path, 'welcome.mp4'),
'sorry':os.path.join(path, 'sorry.mp4'),
'okay':os.path.join(path, 'okay.mp4'),
'what':os.path.join(path, 'what.mp4'),
'how':os.path.join(path, 'how.mp4'),
'you':os.path.join(path, 'you.mp4'),
'meet':os.path.join(path, 'meet.mp4'),
'i':os.path.join(path, 'i.mp4'),
'me':os.path.join(path, 'me.mp4'),
'your':os.path.join(path, 'your.mp4'),
'name':os.path.join(path, 'name.mp4'),
'where':os.path.join(path, 'where.mp4'),
'why':os.path.join(path, 'why.mp4'),
'who':os.path.join(path, 'who.mp4'),
'which':os.path.join(path, 'which.mp4'),
'when':os.path.join(path, 'when.mp4'),
'there':os.path.join(path, 'there.mp4'),
'this':os.path.join(path, 'this.mp4'),
'from':os.path.join(path, 'from.mp4'),
'today':os.path.join(path, 'today.mp4'),
'yourself':os.path.join(path, 'yourself.mp4'),
'uniform':os.path.join(path, 'uniform.mp4'),
'submit':os.path.join(path, 'submit.mp4'),
'give':os.path.join(path, 'give.mp4'),
'exam':os.path.join(path, 'exam.mp4'),
'assignment':os.path.join(path, 'assignment.mp4'),
'teacher':os.path.join(path, 'teacher.mp4'),
'teachers':os.path.join(path, 'teachers.mp4'),
'result':os.path.join(path, 'result.mp4'),
'output':os.path.join(path, 'output.mp4'),
'percentage':os.path.join(path, 'percentage.mp4'),
'first':os.path.join(path, 'first.mp4'),
'class':os.path.join(path, 'class.mp4'),
'division':os.path.join(path, 'division.mp4'),
'rollnumber':os.path.join(path, 'roll_number.mp4'),
'number':os.path.join(path, 'number.mp4'),
'education':os.path.join(path, 'education.mp4'),
'institution':os.path.join(path, 'institution.mp4'),
'college':os.path.join(path, 'college.mp4'),
'engineer':os.path.join(path, 'engineer.mp4'),
'engineering':os.path.join(path, 'engineering.mp4'),
'technology':os.path.join(path, 'technology.mp4'),
'university':os.path.join(path, 'university.mp4'),
'kerala':os.path.join(path, 'kerala.mp4'),
'sign':os.path.join(path, 'sign.mp4'),
'language':os.path.join(path, 'language.mp4'),
'hello':os.path.join(path, 'hello.mp4'),
'indian':os.path.join(path, 'indaian.mp4'),
'bye':os.path.join(path, 'bye_bye.mp4'),
'byebye':os.path.join(path, 'bye_bye.mp4'),
'sunday':os.path.join(path, 'sunday.mp4'),
'monday':os.path.join(path, 'monday.mp4'),
'tuesday':os.path.join(path, 'tuesday.mp4'),
'wednesday':os.path.join(path, 'wednesday.mp4'),
'thursday':os.path.join(path, 'thursday.mp4'),
'friday':os.path.join(path, 'friday.mp4'),
'saturday':os.path.join(path, 'saturday.mp4'),
'helloengineer':os.path.join(path, 'hello_engineer.mp4')
    
}

mapping = {"alphabets": d1, "words": d2}
json_file_path = r'C:\Users\Athira\OneDrive\Documents\Desktop\SIGN_LANGUAGE\mapping.json'

# Write the dictionary to a JSON file
with open(json_file_path, 'w') as json_file:
    json.dump(mapping, json_file, indent=4)

print(f"Mapping saved to {json_file_path}")
# Out:
# Mapping saved to C:\Users\Athira\OneDrive\Documents\Desktop\SIGN_LANGUAGE\mapping.json
